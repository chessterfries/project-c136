# %% [markdown]
# <a href="https://colab.research.google.com/github/chessterfries/project-c136/blob/main/Project_C136.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
data_to_load = files.upload()
# Out:
#      <input type="file" id="files-44c2f1b0-4c0d-4566-bdeb-14bdf609c65a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-44c2f1b0-4c0d-4566-bdeb-14bdf609c65a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv("filtered.csv")
print(df.head())
# Out:
#    Unnamed: 0       Star_name   Distance  Mass  Radius     Gravity
# 0           0             Sun   0.000016   1.0    1.00  274.269161
# 1           1          Sirius   8.600000   2.1    1.71  196.971800
# 2           2         Canopus   4.400000  15.0   71.00  209.511165
# 3           3  Alpha Centauri  37.000000   1.1    1.20  152.371756
# 4           4        Arcturus  25.000000   1.1   26.00  160.836854

# %%
star_name = df["Star_name"]
star_distance = df["Distance"]
star_mass = df["Mass"]
star_radius = df["Radius"]
star_gravity = df["Gravity"]

print(list(star_name))

print(list(star_distance))

print(list(star_mass))

print(list(star_radius))

print(list(star_gravity))
# Out:
# ['Sun', 'Sirius', 'Canopus', 'Alpha Centauri', 'Arcturus', 'Vega', 'Capella', 'Rigel', 'Procyon', 'Betelgeuse', 'Achernar', 'Hadar', 'Altair', 'Acrux', 'Aldebaran', 'Antares', 'Spica', 'Pollux', 'Fomalhaut', 'Deneb', 'Mimosa', 'Regulus', 'Adhara', 'Shaula', 'Castor', 'Gacrux', 'Bellatrix', 'Elnath', 'Miaplacidus', 'Alnilam', 'Gamma Velorum', 'Alnair', 'Alioth', 'Alnitak', 'Dubhe', 'Mirfak', 'Wezen', 'Sargas']
# [1.5813e-05, 8.6, 4.4, 37.0, 25.0, 43.0, 11.4, 17.0, 65.0, 34.0, 25.0, 77.0, 52.0, 88.0, 81.0, 81.0, 80.0, 11.9, 19.92, 10.48, 44.25, 11.41, 36.1, 12.87, 5.98, 6.52, 4.25, 47.5, 18.72, 39.6, 40.3, 7.27, 46.1, 37.7, 87.2, 31.0, 28.6, 57.0]
# [1.0, 2.1, 15.0, 1.1, 1.1, 2.2, 2.6, 23.0, 1.5, 20.0, 6.7, 10.5, 1.8, 18.0, 1.5, 12.0, 11.43, 1.9, 1.9, 19.0, 16.0, 3.8, 12.5, 14.5, 2.8, 1.5, 8.6, 5.0, 3.5, 32.0, 9.0, 4.0, 2.9, 33.0, 4.25, 8.5, 17.0, 5.7]
# ...

# %%
data = files.upload()
# Out:
#      <input type="file" id="files-5ebd51ca-7de4-4832-9da7-f126508bb6fa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ebd51ca-7de4-4832-9da7-f126508bb6fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
